# %% [markdown]
# # Function in Python

# %% [markdown]
# ## Introduction to Functions
#
# Defination:
#
# A function is a block of code that perform a specific task. Fucntions help in organizing code , reusing code , and improving readability.

# %%
## syntax
def function_name(parameters):
  """Docstring"""
  #Function body
  return # expression

# %%
# why functions?
num = 24
if num %2 == 0 :
  print("number is even")
else:
  print("number is odd")
# Out:
# number is even

# %%
def even_or_odd(num):
  """This function finds even or odd"""
  if num %2 == 0:
    print("the number is even")
  else:
    print("the number is odd")

# %%
## call this functions
even_or_odd(24)
# Out:
# the number is even

# %%
## function with multiple parameters

def add(a,b):
 return a+b

result = add(2,4)
print(result)
# Out:
# 6

# %%
### Default Parameters

def greet(name):
  print(f"Hello {name} welcome to the paradise")

greet("Taleeb")
# Out:
# Hello Taleeb welcome to the paradise

# %%
def greet(name = "Guest"):
  print(f"Hello {name} welcome to the paradise")

greet()
greet("Taleeb")
# Out:
# Hello Guest welcome to the paradise
# Hello Taleeb welcome to the paradise

# %%
# variable length agruments
#Positional and Keywords agruments

def print_number(*Taleeb):
  for numbers in Taleeb:
    print(numbers)

print_number(1,2,3,4,5,6,7,"Taleeb")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# Taleeb

# %%
## Positional Arguments
def print_number(*args):
  for numbers in args:
    print(numbers)

print_number(1,2,3,4,5,6,7,"Taleeb")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# Taleeb

# %%
# Keywords Arguments : All the parameters in the form of key value parameters

def print_details(**kwargs):
  for key, value in kwargs.items():
    print(f"{key}:{value}")

print_details(name="taleeb",age="21",country="India")
# Out:
# name:taleeb
# age:21
# country:India

# %%
# both Positinal Agruments & keywords agruments
def print_details(*args,**kwargs):
  for val in args:
    print(f"Positinal agruments: {val}")

  for key, value in kwargs.items():
    print(f"keywords agruments: {key}:{value}")



print_details(1,2,3,4,5,6,7,"Taleeb",name ="taleeb",age ="21",country ="India")
# Out:
# Positinal agruments: 1
# Positinal agruments: 2
# Positinal agruments: 3
# Positinal agruments: 4
# Positinal agruments: 5
# Positinal agruments: 6
# Positinal agruments: 7
# Positinal agruments: Taleeb
# keywords agruments: name:taleeb
# keywords agruments: age:21
# keywords agruments: country:India

# %%
# Retunr Statements
def multiply(a,b):
  return a*b

multiply(2,3)
# Out:
# 6

# %%
# Retunr multiple Parameters
def multiply(a,b):
  return a*b , a

multiply(2,3)
# Out:
# (6, 2)

# %% [markdown]
# ## Function Examples

# %% [markdown]
# ### Example 1 : Temperature Conversion

# %%
def convert_temperature(temp,unit):
  """This function converts temperature between Celsius and Fahreheint"""
  if unit == 'C':
    return temp * 9/5 + 32 ## Celsius to Fahreheint
  elif unit == 'F':
    return (temp - 32) * 5/9 ## Fahreheint to celsius
  else :
    return None
  
print(convert_temperature(25,'C'))
print(convert_temperature(77,'F'))
# Out:
# 77.0
# 25.0

# %% [markdown]
# ### Example 2 : Password strength Checker

# %%
def is_stronge_password(password):
  """This function checks if the password is strong or not"""
  if len(password)<8:
    return False
  if not any(char.isdigit() for char in password):
   return False
  if not any(char.islower() for char in password):
    return False
  if not any(char.isupper() for char in password):
    return False
  if not any(char in '!@#$%^&*()_+' for char in password):
    return False
  return True 

## Calling the function
print(is_stronge_password("Weakpwd"))
print(is_stronge_password("Str0ngPwd!"))
# Out:
# False
# True

# %% [markdown]
# ### Example 3 : Calculate the total Cost of items in a shopping Cart

# %%
def calculate_total_cost(cart):
  total_cost = 0
  for item in cart:
    total_cost += item['price']*item['Quantity']

  return total_cost  
  

## Example cart data
cart = [
  {'name':'apple','price':0.5,'Quantity':4},
  {'name':'Banana','price':0.3,'Quantity':6},
  {'name':'Orange','price':0.7,'Quantity':12}
]


## calling the function
total_cost = calculate_total_cost(cart)
print(total_cost)
# Out:
# 12.2

# %% [markdown]
# ### Example 4 : check IF a string Is Palindrome

# %%
def is_palindrome(s):
    s = s.lower().replace(" ", "")   # remove spaces
    return s == s[::-1]

print(is_palindrome("A man a plan a canal Panama"))  #True
print(is_palindrome("Hello"))  # False
# Out:
# True
# False

# %% [markdown]
# ### Example 5 : Calculate the factorials of number using recusion.

# %%
def factorial(n):
  if n == 0:
    return 1
  else :
    return n * factorial(n-1)
  
print(factorial(6))
# Out:
# 720
